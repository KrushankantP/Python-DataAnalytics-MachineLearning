# %%
import pandas as pd
airbnb =pd.read_csv('Airbnb_Texas_Rentals.csv', index_col=0)

# %%
rate=airbnb['average_rate_per_night'].str.replace('$','')

# %%
rate.head()
# Out:
# 1     27
# 2    149
# 3     59
# 4     60
# 5     75
# Name: average_rate_per_night, dtype: object

# %%
# I want to know wheather ot not there is any missing values
pd.isnull(rate).any()
# Out:
# True

# %%
#we want to know how many missing values
rate.isna().sum()
# Out:
# 28

# %%
#this function does not count "NaN" values.
rate.count()
# Out:
# 18231

# %%
rate=rate.fillna(0).astype(int)

# %%
rate
# Out:
# 1          27
# 2         149
# 3          59
# 4          60
# 5          75
# 6         250
# 7         129
# 8          25
# 9         345
# 10         72
# 11         65
# 12        116
# 13        160
# 14        110
# 15        175
# 16         88
# 17         82
# 18        275
# 19       1500
# 20        250
# 21       2999
# 22        350
# 23        165
# 24         65
# 25        100
# 26          0
# 27         36
# 28         65
# 29        110
# 30        650
#          ...
# 18230      55
# 18231     300
# 18232     100
# 18233     487
# 18234      40
# 18235      45
# 18236      82
# 18237     200
# 18238      28
# 18239     101
# 18240      40
# 18241     101
# 18242      34
# 18243      39
# 18244      75
# 18245      90
# 18246      75
# 18247     299
# 18248      48
# 18249      75
# 18250      37
# 18251      27
# 18252     149
# 18253      31
# 18254      38
# 18255      60
# 18256      99
# 18257      13
# 18258      65
# 18259      75
# ...

# %%
bools= rate<0
bools.any()
# Out:
# False

# %%
#there are several solutions, dropna, or replace with mean or only calculate rate >0

# %%
rate[rate>0].mean()
# Out:
# 211.5397400032911

# %%
airbnb
# Out:
#       average_rate_per_night bedrooms_count             city date_of_listing  \
# 1                        $27              2           Humble        May 2016
# 2                       $149              4      San Antonio   November 2010
# 3                        $59              1          Houston    January 2017
# 4                        $60              1            Bryan   February 2016
# 5                        $75              2       Fort Worth   February 2017
# 6                       $250              4           Conroe     August 2016
# 7                       $129              3      Cedar Creek      March 2016
# 8                        $25              1       Fort Worth    January 2016
# 9                       $345              3         Rockport   February 2016
# 10                       $72         Studio      San Antonio     August 2013
# 11                       $65              1           Irving       July 2015
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-c798d9adbec1> in <module>
# ----> 1 rate[['bedrooms_count']=='2'].mean()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
two_bed = airbnb[airbnb['bedrooms_count']=='2'].mean()
two_bed
# Out:
# latitude     30.366392
# longitude   -97.165955
# dtype: float64
